# %%
import pandas as pd

# %%
data = pd.read_csv('../../data/processed/sleep_cycle_productivity_cleaned.csv')

# %%
data
# Out:
#             Date  Age  Gender  Sleep Start Time  Sleep End Time  \
# 0     2024-04-12   30       2             23.33            4.61
# 1     2024-11-04   40       0             21.02            2.43
# 2     2024-08-31   20       1             22.10            3.45
# 3     2024-02-22   30       2             23.10            6.65
# 4     2024-02-23   40       2             21.42            4.17
# ...          ...  ...     ...               ...             ...
# 4995  2024-01-03   30       0             22.78            4.15
# 4996  2024-06-02   50       1             21.48            5.39
# 4997  2024-08-13   40       0             22.02            2.82
# 4998  2024-12-26   50       2             23.47            7.87
# 4999  2024-04-11   50       1             20.72            1.37
#
#       Total Sleep Hours  Sleep Quality  Exercise (mins/day)  \
# 0                  5.28              3                   86
# 1                  5.41              5                   32
# ...

# %%
data.describe()
# Out:
#                Age       Gender  Sleep Start Time  Sleep End Time  \
# count  5000.000000  5000.000000       5000.000000     5000.000000
# mean     33.886000     0.986400         22.005350        4.980262
# std      12.320283     0.810152          1.157591        1.862508
# min      10.000000     0.000000         20.000000        0.560000
# 25%      20.000000     0.000000         21.020000        3.660000
# 50%      30.000000     1.000000         22.020000        4.970000
# 75%      40.000000     2.000000         23.000000        6.310000
# max      50.000000     2.000000         23.980000        9.420000
#
#        Total Sleep Hours  Sleep Quality  Exercise (mins/day)  \
# count        5000.000000    5000.000000          5000.000000
# mean            6.974902       5.520800            43.962600
# std             1.454033       2.863845            25.798541
# min             4.500000       1.000000             0.000000
# 25%             5.690000       3.000000            22.000000
# ...

# %%
data['Age'].value_counts()
# Out:
# Age
# 50    1235
# 40    1171
# 20    1164
# 30    1163
# 10     267
# Name: count, dtype: int64

# %%
data['Age'].value_counts(normalize=True)
# Out:
# Age
# 50    0.2470
# 40    0.2342
# 20    0.2328
# 30    0.2326
# 10    0.0534
# Name: proportion, dtype: float64

# %%
data.columns
# Out:
# Index(['Date', 'Age', 'Gender', 'Sleep Start Time', 'Sleep End Time',
#        'Total Sleep Hours', 'Sleep Quality', 'Exercise (mins/day)',
#        'Screen Time Before Bed (mins)', 'Work Hours (hrs/day)',
#        'Productivity Score', 'Mood Score', 'Stress Level', 'Weekday'],
#       dtype='object')

# %%
cols = ['Age', 'Gender','Sleep Quality', 'Weekday']

for i in cols:
  print(data[i].value_counts())
# Out:
# Age
# 50    1235
# 40    1171
# 20    1164
# 30    1163
# 10     267
# Name: count, dtype: int64
# Gender
# 1    1718
# 0    1675
# 2    1607
# Name: count, dtype: int64
# Sleep Quality
# 5     521
# 10    521
# 7     517
# 4     508
# 2     503
# 8     491
# 3     490
# 6     489
# 9     480
# 1     480
# Name: count, dtype: int64
# Weekday
# Saturday     744
# Sunday       739
# Tuesday      720
# Friday       716
# Monday       712
# Thursday     689
# Wednesday    680
# Name: count, dtype: int64

# %%
cols = ['Age', 'Gender','Sleep Quality', 'Weekday']

for i in cols:
  print(data[i].value_counts(normalize=True))
# Out:
# Age
# 50    0.2470
# 40    0.2342
# 20    0.2328
# 30    0.2326
# 10    0.0534
# Name: proportion, dtype: float64
# Gender
# 1    0.3436
# 0    0.3350
# 2    0.3214
# Name: proportion, dtype: float64
# Sleep Quality
# 5     0.1042
# 10    0.1042
# 7     0.1034
# 4     0.1016
# 2     0.1006
# 8     0.0982
# 3     0.0980
# 6     0.0978
# 9     0.0960
# 1     0.0960
# Name: proportion, dtype: float64
# Weekday
# Saturday     0.1488
# Sunday       0.1478
# Tuesday      0.1440
# Friday       0.1432
# Monday       0.1424
# Thursday     0.1378
# Wednesday    0.1360
# Name: proportion, dtype: float64
